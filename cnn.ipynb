# %%
import matplotlib.pyplot as plt
import numpy as np
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
import pathlib

data_dir=r'./AITEX_DATA'
data_dir = pathlib.Path(data_dir).with_suffix('')

# %%
image_count = len(list(data_dir.glob('*/*.png')))
print(image_count)
# Out:
# 247

# %%
defective = list(data_dir.glob('Defect_images/*'))
PIL.Image.open(str(defective[0]))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=4096x256>

# %%
batch_size = 32
img_height = 180
img_width = 180
